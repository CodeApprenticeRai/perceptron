# %%
#prep data
#create perceptron class
#train on training data
#test on testing data, see test data error drop
#graph test error

#create perceptron class

'''
# !first I need to know what shape the data is gonna 
'''
class perceptron:

# %%
#prep data

#get data
from os import listdir
from os.path import isfile

base_data_path = "./data"

data_filenames = {
    "test": [],
    "train": []
} 

#!! assign labels
for directory_name in listdir(base_data_path): #cocacola or pepsi
    in_memory_data_path = data_filenames[directory_name]
    subpath = base_data_path + "/" +  directory_name
    for subdirectory in listdir(subpath):
        file_path_base = subpath +  "/" + subdirectory
        i = 0
        for filename in listdir(file_path_base):
            file_path = file_path_base + "/" + filename
            in_memory_data_path.append(file_path)

            
from pprint import pprint
pprint(data_filenames)
# Out:
# {'test': ['./data/test/cocacola/0.jpg',
#           './data/test/cocacola/1.jpg',
#           './data/test/cocacola/10.jpg',
#           './data/test/cocacola/11.jpg',
#           './data/test/cocacola/12.jpg',
#           './data/test/cocacola/13.jpg',
#           './data/test/cocacola/14.jpg',
#           './data/test/cocacola/15.jpg',
#           './data/test/cocacola/16.jpg',
#           './data/test/cocacola/17.jpg',
#           './data/test/cocacola/18.jpg',
#           './data/test/cocacola/19.jpg',
#           './data/test/cocacola/2.jpg',
#           './data/test/cocacola/20.jpg',
#           './data/test/cocacola/21.jpg',
#           './data/test/cocacola/22.jpg',
#           './data/test/cocacola/23.jpg',
#           './data/test/cocacola/24.jpg',
#           './data/test/cocacola/25.jpg',
#           './data/test/cocacola/26.jpg',
#           './data/test/cocacola/27.jpg',
#           './data/test/cocacola/28.jpg',
#           './data/test/cocacola/29.jpg',
# ...

# %%
from PIL import Image
import numpy as np

training_data = [ np.array(Image.open(filename, "r")) for filename in data_filenames['train'] ]
test_data = [ np.array(Image.open(filename, "r")) for filename in data_filenames['test'] ]

training_data[:10]
# Out:
# [array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         ...,
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
# ...

# %%
training_data[0].shape
# Out:
# (270, 230, 3)
